# %%
pip install split-folders[full]

# %%
import splitfolders

# Define paths
input_folder = '/content/drive/Othercomputers/My Laptop/RoadImagesDataSet/RawFilesV2'  # Replace with your data folder path
output_folder = '/content/drive/Othercomputers/My Laptop/RoadImagesDataSet/Oversampling'  # Replace with your desired output folder path


# Set the seed for reproducibility
seed = 1337

# Split with a fixed number and enable oversampling
splitfolders.fixed(input_folder, output=output_folder,
                   seed=seed, fixed=(70, 30), oversample=True, group_prefix=None, move=False)
# Out:
# Copying files: 7406 files [19:52,  6.21 files/s]
# Oversampling: 6 classes [05:20, 53.37s/ classes]
